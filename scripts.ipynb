# %%
from scrapers.money_control import scrape_and_save

# %%
scrape_and_save(0, 15, dir_name="articles")
# Out:
# scraping article list...
# page 0 completed...
# page 1 completed...
# page 2 completed...
# page 3 completed...
# page 4 completed...
# page 5 completed...
# page 6 completed...
# page 7 completed...
# page 8 completed...
# page 9 completed...
# page 10 completed...
# page 11 completed...
# page 12 completed...
# page 13 completed...
# page 14 completed...
# scraping articles...
# scraping https://www.moneycontrol.com/news/india/karnataka-govt-to-woo-ev-companies-to-set-up-manufacturing-plants-12795084.html...
# scraping https://www.moneycontrol.com/news/business/moneycontrol-research/concor-correction-spells-long-term-opportunity-12794865.html...
# article https://www.moneycontrol.com/news/business/moneycontrol-research/concor-correction-spells-long-term-opportunity-12794865.html contains no content, skipping...
# scraping https://www.moneycontrol.com/news/business/earnings/rategain-q1fy25-a-soft-quarter-all-eyes-on-acquisitions-12794658.html...
# ...
